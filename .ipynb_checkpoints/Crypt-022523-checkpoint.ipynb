# %%
# IMPORT STATEMENTS
import sys
sys.path.append("/booleanfs2/sahoo/Hegemon/")
sys.path = ["/booleanfs2/sahoo/BoNE/"] + sys.path

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3
        
import SMaRT.MacUtils as mut
reload(mut)
# Out:
# <module 'SMaRT.MacUtils' from '/booleanfs2/sahoo/BoNE/SMaRT/MacUtils.py'>

# %%
import bone
reload(bone)
# adult small intestine version 2
def get_adult_Human_small_Intestinal(self, tn=1):
    self.prepareData("T9_1", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("ArrayID")
    atypes = ['Top', 'Bottom']
    ahash = {
        'crypt-upper-cut1-A1':0, 'crypt-upper-cut2-A1':0, 'crypt-upper-cut3-A1':0, 'crypt-upper-cut4-A1':0,
        'crypt-upper-cut1-B1':0, 'crypt-upper-cut2-B1':0, 'crypt-upper-cut1-C1':0,
        'crypt-down-cut3-B1':1,
        'crypt-down-cut1-C1':1, 'crypt-down-cut1-A1':1,}
    self.initData(atype, atypes, ahash)    
    return
bone.IBDAnalysis.get_adult_Human_small_Intestinal = get_adult_Human_small_Intestinal
# validation adult 
def get_adult_GSE158328_A_1_2_v1(self, tn=1):
    self.prepareData("T12_22", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("ArrayID")
    atypes = ['Top', 'Bottom']
    ahash = {
        'crypt-upper-cut2-A2':0, 'crypt-upper-cut3-A2':0,
        'extend-crypt-upper-cut1-A1':0, 'extend-crypt-upper-cut2-A1':0, 'extend-crypt-upper-cut3-A1':0,
        'crypt-down-cut3-A2':1,'crypt-down-cut4-A2':1,  
        'extend-crypt-down-cut1-A1':1, 'extend-crypt-down-cut2-A1':1,}
    self.initData(atype, atypes, ahash)    
    return
bone.IBDAnalysis.get_adult_GSE158328_A_1_2_v1 = get_adult_GSE158328_A_1_2_v1
# fetal slide A4 and A6
def get_dev_fetal_v2(self, tn=1):
    self.prepareData("T12_6", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("ArrayID")
    atypes = ['Top', 'Bottom']
    ahash = {
        'crypt-upper-cut1-A4':0, 'crypt-upper-cut2-A4':0,
        'crypt-upper-cut1-A6':0, 'crypt-upper-cut2-A6':0, 'crypt-upper-cut3-A6':0, 
        'crypt-down-cut1-A4':1,  'crypt-down-cut2-A4':1, 
        'crypt-down-cut3-A4':1, 'crypt-down-cut4-A4':1,
        'crypt-down-cut1-A6':1, 'crypt-down-cut2-A6':1,}
    self.initData(atype, atypes, ahash)    
    return
bone.IBDAnalysis.get_dev_fetal_v2 = get_dev_fetal_v2
def getJung2011(self, tn=1):
    self.prepareData("CRC110")
    h = self.h
    atype = h.getSurvName('c ephb2 surface abundance')
    atypes = ['EPHB2 neg', 'EPHB2 low', 'EPHB2 medium', 'EPHB2 high']
    ahash = {}
    if (tn == 2):
        atypes = ['Top', 'Bottom']
        ahash = {'EPHB2 neg':0, 'EPHB2 low':0, 'EPHB2 medium':1, 'EPHB2 high':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getJung2011 = getJung2011
def getJung2015(self, tn=1):
    self.prepareData("ORG7")
    h = self.h
    atype = h.getSurvName('c ptk7 surface abundance')
    atypes = ['PTK7 negative', 'PTK7 low', 'PTK7 medium', 'PTK7 high']
    ahash = {}
    if (tn == 2):
        atypes = ['Top', 'Bottom']
        ahash = {'PTK7 negative':0, 'PTK7 low':0, 'PTK7 medium':1, 'PTK7 high':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getJung2015 = getJung2015
def getMerlosSuarez2011(self, tn=1):
    self.prepareData("CRC109")
    h = self.h
    atype = h.getSurvName('c group')
    atypes = ['EphB2 High', 'EphB2 Medium', 'EphB2 Low', 'Lgr5 High', 'Lgr5 Low']
    ahash = {}
    if (tn == 2):
        atypes = ['Top', 'Bottom']
        ahash = {'EphB2 High':1, 'EphB2 Medium':0, 'EphB2 Low':0, 'Lgr5 High':1,
                'Lgr5 Low':0}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getMerlosSuarez2011 = getMerlosSuarez2011
def getQu2016(self, tn=1):
    self.prepareData("PLP50")
    atype = self.h.getSurvName("c tissue type")
    atypes = ['NS', 'NC', 'A', 'C', 'M']
    ahash = {'Metastasis':4,
            'Carcinoma':3,
            'Normal crypt epithelium':1,
            'Adenoma':2,
            'Normal surface epithelium':0}
    if (tn == 2):
        atypes = ['NS', 'NC']
        ahash = {'Normal crypt epithelium':1,
                'Normal surface epithelium':0}
    if (tn == 3):
        atypes = ['NC', 'A']
        ahash = {'Normal crypt epithelium':0, 'Adenoma':1}
    if (tn == 4):
        atypes = ['NC', 'C']
        ahash = {'Normal crypt epithelium':0, 'Carcinoma':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getQu2016 = getQu2016 
def getTan2019(self, tn=1):
    self.prepareData("GC38", "/Users/dtv004/public_html/Hegemon/explore.conf")
    tissue = self.h.getSurvName("c tissue (ch1)")
    ahash = {'Pylorus':0, 'Small intestine':1, 'Colon':2}
    atype = self.h.getSurvName('c population (ch1)')
    atypes = ['Lgr5Hi', 'Lgr5Lo', 'Whole', 'Lgr5Neg', 'Aqp5Pos', 'Aqp5Neg']
    if (tn == 2):
        atypes = ['Top', 'Bottom']
        ahash = {'Lgr5Hi':1, 'Lgr5Lo':0, 'Lgr5Neg':0}
        atype = [atype[i] if tissue[i] == 'Colon'
                 else None for i in range(len(atype))]
    if (tn == 3):
        atypes = ['Top', 'Bottom']
        ahash = {'Lgr5Hi':1, 'Lgr5Lo':0, 'Lgr5Neg':0}
        atype = [atype[i] if tissue[i] == 'Small intestine'
                 else None for i in range(len(atype))]
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getTan2019 = getTan2019
def getHong2018(self, tn=1):
    self.prepareData("CRC161")
    atype = self.h.getSurvName("c title")
    atype = [mut.re.sub(",.*", "", str(k)) for k in atype]
    atype = [mut.re.sub("mucosa ", "", str(k)) for k in atype]
    atype = [mut.re.sub(" fraction", "", str(k)) for k in atype]
    atype = [mut.re.sub("next to ", "", str(k)) for k in atype]
    atypes = ['Top', 'Bottom']
    ahash = {'top crypt':0, 'bottom crypt':1, 'tumor top crypt':0, 'tumor bottom crypt':1}
    if (tn == 2):
        atypes = ['Top', 'Bottom']
        ahash = {'top crypt':0, 'bottom crypt':1}
    if (tn == 3):
        atypes = ['Top', 'Bottom']
        ahash = {'tumor top crypt':0, 'tumor bottom crypt':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getHong2018 = getHong2018

# %%
def getScott2022(self, tn=1):
    self.prepareData("N12", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("c cellType (ch1)")
    atypes = [ 'EEC', 'FAE', 'paneth', 'TA', 'tuft', 'BEST4+','secretory_prog', 'goblet', 'ISC', 'absorptive']
    ahash = {}
    if (tn == 2):
        atypes = ['Top', 'Bottom']
        ahash = {'paneth':1, 'ISC':1, 'absorptive':0}
        self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getScott2022 = getScott2022
def getWang2019(self, tn=1):
    self.prepareData("T45", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("c type")
    atypes = ['Top', 'Bottom']
    ahash = {'Enterocyte':0, 'Stem Cell':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getWang2019 = getWang2019
def getHaber2017LCS(self, tn=1):
    self.prepareData("T54", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("c type")
    atypes = ['Top', 'Bottom']
    ahash = {'Enterocyte.dist':0, 'Enterocyte.prox':0, 'Stem':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getHaber2017LCS = getHaber2017LCS
def getHaber2017OR(self, tn=1):
    self.prepareData("T55", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("c type")
    atypes = ['Top', 'Bottom']
    ahash = {'Enterocyte.1':0, 'Enterocyte.2':0,'Enterocyte.Progenitor':0,
             'Enterocyte.Progenitor.Late':0, 'Stem':1}
    if (tn == 2):
        atypes = ['Top', 'Bottom']
        ahash = {'Enterocyte.Progenitor':0,'Enterocyte.Progenitor.Late':0, 'Stem':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getHaber2017OR = getHaber2017OR
def getHaber2017R(self, tn=1):
    self.prepareData("T56", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("c type")
    atypes = ['Top', 'Bottom']
    ahash = {'Enterocyte':0, 'Stem':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getHaber2017R = getHaber2017R           
def getHaber2017SalmHelm(self, tn=1):
    self.prepareData("T57", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("c type")
    atypes = ['Top', 'Bottom']
    ahash = {'Enterocyte':0,'Enterocyte.Progenitor':0, 'Stem':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getHaber2017SalmHelm = getHaber2017SalmHelm      
def getHaber2017SalmonellaInfect(self, tn=1):
    self.prepareData("T58", cfile="/Users/m2haque/public_html/Hegemon/explore.conf")
    atype = self.h.getSurvName("c type")
    atypes = ['Top', 'Bottom']
    ahash = {'Enterocyte.dist':0, 'Enterocyte.prox':0, 'Enterocyte.prog':0, 'Stem':1}
    self.initData(atype, atypes, ahash)
    return
bone.IBDAnalysis.getHaber2017SalmonellaInfect = getHaber2017SalmonellaInfect

# %%
def getAdultDeg():
    dir1 = "/booleanfs2/sahoo/Data/BooleanLab/m2haque/B_Analysis/deg_analysis/"
    cfile = dir1 + "adult_condition_treated_results.csv"
    df = mut.pd.read_csv(cfile)
    wt1, l1 = [-1, 1], [list(df[(df["padj"]<0.01) & (df["log2FoldChange"]<-1)]['Unnamed: 0']),
                        list(df[(df["padj"]<0.01) & (df["log2FoldChange"]>1)]['Unnamed: 0'])]
    return wt1, l1
def getFetalDegVersion4():
    dir1 = "/booleanfs2/sahoo/Data/BooleanLab/m2haque/B_Analysis/deg_analysis/"
    cfile = dir1 + "fetal_condition_treated_results.csv"
    df = mut.pd.read_csv(cfile)
    wt1, l1 = [-1, 1], [list(df[(df["padj"]<0.01) & (df["log2FoldChange"]<-1)]['Unnamed: 0']),
                        list(df[(df["padj"]<0.01) & (df["log2FoldChange"]>1)]['Unnamed: 0'])]
    return wt1, l1
#I C A M  
def getAdultDegMac1():
    dir1 = "/booleanfs2/sahoo/Data/BooleanLab/m2haque/B_Analysis/deg_analysis/"
    cfile = dir1 + "adult_condition_treated_results.csv"
    df = mut.pd.read_csv(cfile)
    top1 = list(df[df["log2FoldChange"]<-0.25]['Unnamed: 0'])
    bottom1 = list(df[df["log2FoldChange"]>0.25]['Unnamed: 0'])
    df = mut.pd.read_csv("deGenes/jung-2015-diff.txt", sep="\t", header=None)
    top2 = list(df[(df[4] > 0.02)][1])
    bottom2 = list(df[(df[4] < 0)][1])
    wt1, l1 = mut.getCls13a14a3()
    s1 = set(l1[0]).intersection(top1).intersection(bottom2)
    s2 = set(l1[1]).intersection(bottom1).intersection(top2)
    s3 = set(l1[2]).intersection(bottom1).intersection(top2)
    return wt1, [s1, s2, s3]
# I C B M
def getAdultDegMac2():
    dir1 = "/booleanfs2/sahoo/Data/BooleanLab/m2haque/B_Analysis/deg_analysis/"
    cfile = dir1 + "adult_condition_treated_results.csv"
    df = mut.pd.read_csv(cfile)
    top1 = list(df[df["log2FoldChange"]<-0.25]['Unnamed: 0'])
    bottom1 = list(df[df["log2FoldChange"]>0.25]['Unnamed: 0'])
    df = mut.pd.read_csv("deGenes/jung-2015-diff.txt", sep="\t", header=None)
    top2 = list(df[(df[4] > 0.02)][1])
    bottom2 = list(df[(df[4] < 0)][1])
    wt1, l1 = mut.getCls13a14a3()
    s1 = set(l1[0]).intersection(top1).intersection(top2)
    s2 = set(l1[1]).intersection(bottom1).intersection(bottom2)
    s3 = set(l1[2]).intersection(bottom1).intersection(bottom2)
    return wt1, [s1, s2, s3]

# %%
# wt1, l1 = getAdultDeg() # ADULT DEGs version 2
# wt1, l1 = getFetalDegVersion4() # FETAL DEGs 
wt1, l1 = getAdultDegMac1()  #ICAM
# wt1, l1 = getAdultDegMac2()  #IC Biased M
ana = bone.IBDAnalysis()

# ana.get_adult_Human_small_Intestinal() # Adult small intestine
# ana.get_dev_fetal_v2() #fetal - SLIDE A4 and A6
# ana.get_adult_GSE158328_A_1_2_v1() # adult validation large intestine slide A1 and A2
# ana.getGEOMacAnnICAMtest(3)
# ana.getMerlosSuarez2011(2)
# ana.getJung2011(2)
# ana.getJung2015(2)
ana.getQu2016(2) # surface vs Crypt (circular glands)
# ana.getTan2019(2) # Colon
# ana.getTan2019(3) # Small Intestine
# ana.getHong2018(3)
# ana.getScott2022(2)
# ana.getWang2019(1) # top and bottom
# ana.getHaber2017FAE(1)
# ana.getHaber2017LCS(1) # well defined getAdultDegMac
# ana.getHaber2017OR(1)
# ana.getHaber2017R(1) # well defined getAdultDegMac
# ana.getHaber2017SalmHelm(1) 
# ana.getHaber2017SalmonellaInfect(1) # well defined getAdultDegMac


fig = bone.processData(ana, l1, wt1, desc=None, violin=1)
# ana.order
# print(" ".join([str(ana.atype[i]) for i in ana.i1]))
# strname = str(ana.name)
# fig.savefig(f'degs_{strname}.pdf', dpi=100, transparent=True,bbox_inches = 'tight')
# Out:
# Qu 2016 Normal Adenoma Cancer (n = 58)
# GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50
# 13 [6, 7] GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50 PLP50
# [12, 58, 59]

# %% [raw]
# Comparative Analysis

# %%
from matplotlib import pyplot as plt
acolor = ["#00CC00", "#D8A03D","#EC008C",
          'cyan', "#B741DC", "#808285",
          'blue', 'black', 'green', 'red',
          'orange', 'brown', 'pink', 'purple']
def plotViolinBar(ana, desc=None):
    global acolor
    fig = plt.figure(figsize=(5,7), dpi=100)
    plt.subplots_adjust(hspace=0, wspace=0)

    ax1 = plt.subplot2grid((10, 1), (0, 0))
    ax2 = plt.subplot2grid((10, 1), (2, 0), rowspan=5)
    params = {'spaceAnn': len(ana.order)/len(ana.atypes), 'tAnn': 1, 'widthAnn':1,
              'genes': [], 'ax': ax1, 'acolor': acolor}
    ax = ana.printTitleBar(params)
    res = ana.getROCAUC()
    ax.text(len(ana.cval[0]), 4, res)
#     res = ana.getMetrics(ana.cval[0])
#     ax.text(len(ana.cval[0]), 4, ",".join(res))
    strname = str(ana.source +" " + ana.name)
    if desc is not None:
        ax.text(-1, 2, strname, horizontalalignment='right',
                    verticalalignment='center')
    params = {'spaceAnn': len(ana.order)/len(ana.atypes), 'tAnn': 1, 'widthAnn':1,
            'genes': [], 'ax': ax2, 'acolor': acolor, 'vert': 0}
    ax.text(1, 0.1, strname, horizontalalignment='left', verticalalignment='center', transform=ax.transAxes)
    ax = ana.printViolin(None, params)
    
    return fig

def plotDensityBar(ana, desc=None):
    fig = plt.figure(figsize=(10,10), dpi=100)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    ax1 = plt.subplot2grid((4, 1), (0, 0))
    ax2 = plt.subplot2grid((4, 1), (1, 0), rowspan=4)
    params = {'spaceAnn': len(ana.order)/len(ana.atypes), 'tAnn': 1, 'widthAnn':1,
              'genes': [], 'ax': ax1, 'acolor': acolor}
    ax = ana.printTitleBar(params)
    res = ana.getMetrics(ana.cval[0])
    ax.text(len(ana.cval[0]), 4, ",".join(res))
    if desc is not None:
        ax.text(-1, 2, desc, horizontalalignment='right',
                    verticalalignment='center')
    ax = ana.densityPlot(ax2, acolor)
    return fig

def processData(ana, l1, wt1, desc=None, violin=1):
    ana.orderData(l1, wt1)
    if (violin == 1):
        return plotViolinBar(ana, desc)
    return plotDensityBar(ana, desc)

# %%
Adult DEGs

# %%
def plotValidationMac(ana, l1, wt1, ax):
    ana.orderData(l1, wt1)
    params = {'spaceAnn': len(ana.order)/len(ana.atypes), 
             'tAnn': 1, 'widthAnn':1, 'acolor': acolor,
             'w': 1, 'h': 0.8, 'ax': ax}
    ax = ana.printTitleBar(params)
    res = ana.getROCAUC()
#     print(desc, res)
    desc = ana.name
    ax.text(len(ana.cval[0]), 4, res)
    sNum = str(" (n = " + str(len(ana.order)) + ") ")
    strname1 = str(ana.name)
    strname = str(ana.source+sNum)
    if desc is not None:
        ax.text(-1, 2, strname, horizontalalignment='right',
                    verticalalignment='center')
    ax.text(1, 0.1, "", horizontalalignment='left', verticalalignment='center', transform=ax.transAxes)


def comparativeAnalysis():
    fig = mut.plt.figure(figsize=(10,20), dpi=100)
    n1 = 14
    axlist = []
    for i in range(n1):
        ax = mut.plt.subplot2grid((n1, 1), (i, 0))
        axlist.extend([ax])

    wt1, l1 = getAdultDeg()
     
    ana = bone.IBDAnalysis()
    
    
    ana.getJung2011(2)
    plotValidationMac(ana, l1, wt1, axlist[0])
    
    ana.getJung2015(2)
    plotValidationMac(ana, l1, wt1, axlist[1])
    
    ana.getMerlosSuarez2011(2)
    plotValidationMac(ana, l1, wt1, axlist[2])
    
    ana.getQu2016(2)
    plotValidationMac(ana, l1, wt1, axlist[3])
    
    ana.getTan2019(2)
    plotValidationMac(ana, l1, wt1, axlist[4])
    
    ana.getTan2019(3)
    plotValidationMac(ana, l1, wt1, axlist[5])
    
    ana.getHong2018(3)
    plotValidationMac(ana, l1, wt1, axlist[6])
    
    ana.getScott2022(2)
    plotValidationMac(ana, l1, wt1, axlist[7])
    
    ana.getWang2019(1) 
    plotValidationMac(ana, l1, wt1, axlist[8])
    
    ana.getHaber2017LCS(1) 
    plotValidationMac(ana, l1, wt1, axlist[9])
    
    ana.getHaber2017OR(1)
    plotValidationMac(ana, l1, wt1, axlist[10])
    
    ana.getHaber2017R(1) 
    plotValidationMac(ana, l1, wt1, axlist[11])
    
    ana.getHaber2017SalmHelm(1)
    plotValidationMac(ana, l1, wt1, axlist[12])
    
    ana.getHaber2017SalmonellaInfect(1)
    plotValidationMac(ana, l1, wt1, axlist[13])
          
comparativeAnalysis()
# Out:
# Jung 2011 Human ISC (n = 11)
# GSE31255 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC110
# 11 [5, 6] GSE31255 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC110 CRC110
# [2004, 3278]
# Jung 2015 SC (n = 8)
# GSE68340 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=ORG7
# 8 [4, 4] GSE68340 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=ORG7 ORG7
# [2341, 3598]
# Merlos Suarez 2011 Mouse ISC (n = 8)
# GSE27605 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC109
# 8 [5, 3] GSE27605 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC109 CRC109
# [1571, 2714]
# Qu 2016 Normal Adenoma Cancer (n = 58)
# GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50
# 13 [6, 7] GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50 PLP50
# [1106, 2060]
# Tan 2019 Stem and differentiated popualtions from various mouse gastrointestinal tissues (n = 42)
# ...

# %% [raw]
# Fetal DEGs

# %%
def plotValidationMac(ana, l1, wt1, ax):
    ana.orderData(l1, wt1)
    params = {'spaceAnn': len(ana.order)/len(ana.atypes), 
             'tAnn': 1, 'widthAnn':1, 'acolor': acolor,
             'w': 1, 'h': 0.8, 'ax': ax}
    ax = ana.printTitleBar(params)
    res = ana.getROCAUC()
#     print(desc, res)
    desc = ana.name
    ax.text(len(ana.cval[0]), 4, res)
    sNum = str(" (n = " + str(len(ana.order)) + ") ")
    strname1 = str(ana.name)
    strname = str(ana.source+sNum)
    if desc is not None:
        ax.text(-1, 2, strname, horizontalalignment='right',
                    verticalalignment='center')
    ax.text(1, 0.1, "", horizontalalignment='left', verticalalignment='center', transform=ax.transAxes)


def comparativeAnalysis():
    fig = mut.plt.figure(figsize=(10,20), dpi=100)
    n1 = 14
    axlist = []
    for i in range(n1):
        ax = mut.plt.subplot2grid((n1, 1), (i, 0))
        axlist.extend([ax])

    wt1, l1 = getFetalDegVersion4()
     
    ana = bone.IBDAnalysis()
    
    
    ana.getJung2011(2)
    plotValidationMac(ana, l1, wt1, axlist[0])
    
    ana.getJung2015(2)
    plotValidationMac(ana, l1, wt1, axlist[1])
    
    ana.getMerlosSuarez2011(2)
    plotValidationMac(ana, l1, wt1, axlist[2])
    
    ana.getQu2016(2)
    plotValidationMac(ana, l1, wt1, axlist[3])
    
    ana.getTan2019(2)
    plotValidationMac(ana, l1, wt1, axlist[4])
    
    ana.getTan2019(3)
    plotValidationMac(ana, l1, wt1, axlist[5])
    
    ana.getHong2018(3)
    plotValidationMac(ana, l1, wt1, axlist[6])
    
    ana.getScott2022(2)
    plotValidationMac(ana, l1, wt1, axlist[7])
    
    ana.getWang2019(1) 
    plotValidationMac(ana, l1, wt1, axlist[8])
    
    ana.getHaber2017LCS(1) 
    plotValidationMac(ana, l1, wt1, axlist[9])
    
    ana.getHaber2017OR(1)
    plotValidationMac(ana, l1, wt1, axlist[10])
    
    ana.getHaber2017R(1) 
    plotValidationMac(ana, l1, wt1, axlist[11])
    
    ana.getHaber2017SalmHelm(1)
    plotValidationMac(ana, l1, wt1, axlist[12])
    
    ana.getHaber2017SalmonellaInfect(1)
    plotValidationMac(ana, l1, wt1, axlist[13])
          
comparativeAnalysis()
# Out:
# Jung 2011 Human ISC (n = 11)
# GSE31255 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC110
# 11 [5, 6] GSE31255 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC110 CRC110
# [481, 118]
# Jung 2015 SC (n = 8)
# GSE68340 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=ORG7
# 8 [4, 4] GSE68340 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=ORG7 ORG7
# [571, 118]
# Merlos Suarez 2011 Mouse ISC (n = 8)
# GSE27605 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC109
# 8 [5, 3] GSE27605 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC109 CRC109
# [340, 117]
# Qu 2016 Normal Adenoma Cancer (n = 58)
# GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50
# 13 [6, 7] GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50 PLP50
# [274, 52]
# Tan 2019 Stem and differentiated popualtions from various mouse gastrointestinal tissues (n = 42)
# ...

# %% [raw]
# SMaRT

# %%
def plotValidationMac(ana, l1, wt1, ax):
    ana.orderData(l1, wt1)
    params = {'spaceAnn': len(ana.order)/len(ana.atypes), 
             'tAnn': 1, 'widthAnn':1, 'acolor': acolor,
             'w': 1, 'h': 0.8, 'ax': ax}
    ax = ana.printTitleBar(params)
    res = ana.getROCAUC()
#     print(desc, res)
    desc = ana.name
    ax.text(len(ana.cval[0]), 4, res)
    sNum = str(" (n = " + str(len(ana.order)) + ") ")
    strname1 = str(ana.name)
    strname = str(ana.source+sNum)
    if desc is not None:
        ax.text(-1, 2, strname, horizontalalignment='right',
                    verticalalignment='center')
    ax.text(1, 0.1, "", horizontalalignment='left', verticalalignment='center', transform=ax.transAxes)


def comparativeAnalysis():
    fig = mut.plt.figure(figsize=(10,20), dpi=100)
    n1 = 14
    axlist = []
    for i in range(n1):
        ax = mut.plt.subplot2grid((n1, 1), (i, 0))
        axlist.extend([ax])

    wt1, l1 = mut.getCls13a14a3()
     
    ana = bone.IBDAnalysis()
    
    ana.getJung2011(2)
    plotValidationMac(ana, l1, wt1, axlist[0])
    
    ana.getJung2015(2)
    plotValidationMac(ana, l1, wt1, axlist[1])
    
    ana.getMerlosSuarez2011(2)
    plotValidationMac(ana, l1, wt1, axlist[2])
    
    ana.getQu2016(2)
    plotValidationMac(ana, l1, wt1, axlist[3])
    
    ana.getTan2019(2)
    plotValidationMac(ana, l1, wt1, axlist[4])
    
    ana.getTan2019(3)
    plotValidationMac(ana, l1, wt1, axlist[5])
    
    ana.getHong2018(3)
    plotValidationMac(ana, l1, wt1, axlist[6])
    
    ana.getScott2022(2)
    plotValidationMac(ana, l1, wt1, axlist[7])
    
    ana.getWang2019(1) 
    plotValidationMac(ana, l1, wt1, axlist[8])
    
    ana.getHaber2017LCS(1) 
    plotValidationMac(ana, l1, wt1, axlist[9])
    
    ana.getHaber2017OR(1)
    plotValidationMac(ana, l1, wt1, axlist[10])
    
    ana.getHaber2017R(1) 
    plotValidationMac(ana, l1, wt1, axlist[11])
    
    ana.getHaber2017SalmHelm(1)
    plotValidationMac(ana, l1, wt1, axlist[12])
    
    ana.getHaber2017SalmonellaInfect(1)
    plotValidationMac(ana, l1, wt1, axlist[13])
          
comparativeAnalysis()
# Out:
# Jung 2011 Human ISC (n = 11)
# GSE31255 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC110
# 11 [5, 6] GSE31255 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC110 CRC110
# [106, 361, 351]
# Jung 2015 SC (n = 8)
# GSE68340 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=ORG7
# 8 [4, 4] GSE68340 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=ORG7 ORG7
# [146, 394, 429]
# Merlos Suarez 2011 Mouse ISC (n = 8)
# GSE27605 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC109
# 8 [5, 3] GSE27605 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC109 CRC109
# [82, 248, 266]
# Qu 2016 Normal Adenoma Cancer (n = 58)
# GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50
# 13 [6, 7] GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50 PLP50
# [84, 255, 255]
# Tan 2019 Stem and differentiated popualtions from various mouse gastrointestinal tissues (n = 42)
# ...

# %% [raw]
# ICBM

# %%
def plotValidationMac(ana, l1, wt1, ax):
    ana.orderData(l1, wt1)
    params = {'spaceAnn': len(ana.order)/len(ana.atypes), 
             'tAnn': 1, 'widthAnn':1, 'acolor': acolor,
             'w': 1, 'h': 0.8, 'ax': ax}
    ax = ana.printTitleBar(params)
    res = ana.getROCAUC()
#     print(desc, res)
    desc = ana.name
    ax.text(len(ana.cval[0]), 4, res)
    sNum = str(" (n = " + str(len(ana.order)) + ") ")
    strname1 = str(ana.name)
    strname = str(ana.source+sNum)
    if desc is not None:
        ax.text(-1, 2, strname, horizontalalignment='right',
                    verticalalignment='center')
    ax.text(1, 0.1, "", horizontalalignment='left', verticalalignment='center', transform=ax.transAxes)


def comparativeAnalysis():
    fig = mut.plt.figure(figsize=(10,20), dpi=100)
    n1 = 14
    axlist = []
    for i in range(n1):
        ax = mut.plt.subplot2grid((n1, 1), (i, 0))
        axlist.extend([ax])

    wt1, l1 = getAdultDegMac2()
     
    ana = bone.IBDAnalysis()
    
    ana.getJung2011(2)
    plotValidationMac(ana, l1, wt1, axlist[0])
    
    ana.getJung2015(2)
    plotValidationMac(ana, l1, wt1, axlist[1])
    
    ana.getMerlosSuarez2011(2)
    plotValidationMac(ana, l1, wt1, axlist[2])
    
    ana.getQu2016(2)
    plotValidationMac(ana, l1, wt1, axlist[3])
    
    ana.getTan2019(2)
    plotValidationMac(ana, l1, wt1, axlist[4])
    
    ana.getTan2019(3)
    plotValidationMac(ana, l1, wt1, axlist[5])
    
    ana.getHong2018(3)
    plotValidationMac(ana, l1, wt1, axlist[6])
    
    ana.getScott2022(2)
    plotValidationMac(ana, l1, wt1, axlist[7])
    
    ana.getWang2019(1) 
    plotValidationMac(ana, l1, wt1, axlist[8])
    
    ana.getHaber2017LCS(1) 
    plotValidationMac(ana, l1, wt1, axlist[9])
    
    ana.getHaber2017OR(1)
    plotValidationMac(ana, l1, wt1, axlist[10])
    
    ana.getHaber2017R(1) 
    plotValidationMac(ana, l1, wt1, axlist[11])
    
    ana.getHaber2017SalmHelm(1)
    plotValidationMac(ana, l1, wt1, axlist[12])
    
    ana.getHaber2017SalmonellaInfect(1)
    plotValidationMac(ana, l1, wt1, axlist[13])
          
comparativeAnalysis()
# Out:
# Jung 2011 Human ISC (n = 11)
# GSE31255 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC110
# 11 [5, 6] GSE31255 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC110 CRC110
# [30, 214, 175]
# Jung 2015 SC (n = 8)
# GSE68340 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=ORG7
# 8 [4, 4] GSE68340 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=ORG7 ORG7
# [41, 221, 209]
# Merlos Suarez 2011 Mouse ISC (n = 8)
# GSE27605 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC109
# 8 [5, 3] GSE27605 http://hegemon.ucsd.edu/Tools/explore.php?key=colon&id=CRC109 CRC109
# [30, 129, 125]
# Qu 2016 Normal Adenoma Cancer (n = 58)
# GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50
# 13 [6, 7] GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50 PLP50
# [27, 151, 135]
# Tan 2019 Stem and differentiated popualtions from various mouse gastrointestinal tissues (n = 42)
# ...

# %% [raw]
# Gene set analysis

# %%
def getCOATES():
    f1 = "./testCrypt/COATES_MACROPHAGE_M1_VS_M2_UP.txt"
    f2 = "./testCrypt/COATES_MACROPHAGE_M1_VS_M2_DN.txt"
    with open(f1) as file:
        up_COATES = [line.rstrip() for line in file]
    with open(f2) as file:
        dn_COATES = [line.rstrip() for line in file]
    wt1, l1 = [1, -1], [up_COATES, dn_COATES]
    return wt1, l1
def getYarilina():
    f1 = "./testCrypt/GSE10500_ARTHRITIC_VS_HEALTHY_MACROPHAGE_UP.txt"
    f2 = "./testCrypt/GSE10500_ARTHRITIC_VS_HEALTHY_MACROPHAGE_DN.txt"
    with open(f1) as file:
        up = [line.rstrip() for line in file]
    with open(f2) as file:
        dn = [line.rstrip() for line in file]
    wt1, l1 = [1, -1], [up, dn]
    return wt1, l1
def getRivollier():
    f1 = "./testCrypt/GSE27859_MACROPHAGE_VS_DC_UP.txt"
    f2 = "./testCrypt/GSE27859_MACROPHAGE_VS_DC_DN.txt"
    with open(f1) as file:
        up = [line.rstrip() for line in file]
    with open(f2) as file:
        dn = [line.rstrip() for line in file]
    wt1, l1 = [1, -1], [up, dn]
    return wt1, l1
def getFOSTER():
    f1 = "./testCrypt/FOSTER_TOLERANT_MACROPHAGE_UP.txt"
    f2 = "./testCrypt/FOSTER_TOLERANT_MACROPHAGE_DN.txt"
    with open(f1) as file:
        up = [line.rstrip() for line in file]
    with open(f2) as file:
        dn = [line.rstrip() for line in file]
    wt1, l1 = [1, -1], [up, dn]
    return wt1, l1
def getMartinez():
    f1 = "./testCrypt/GSE35435_RESTING_VS_IL4_TREATED_MACROPHAGE_UP.txt" 
    f2 = "./testCrypt/GSE35435_RESTING_VS_IL4_TREATED_MACROPHAGE_DN.txt" 
    with open(f1) as file:
        up = [line.rstrip() for line in file]
    with open(f2) as file:
        dn = [line.rstrip() for line in file]
    wt1, l1 = [1, -1], [up, dn]
    return wt1, l1

# %% [raw]
# Dot plots

# %%
import cv2
import re
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
import matplotlib.patches as patches
import matplotlib.colors as colors
import PIL
import math
get_ipython().magic('matplotlib inline')
import pandas as pd
import seaborn as sns
import json
from scipy.stats import fisher_exact, ttest_ind
from collections import Counter
from pprint import pprint
import os
import pickle
import sys
import plotnine as p9
sys.path.append("/booleanfs/sahoo/scripts/")
sys.path.append("/booleanfs2/sahoo/Hegemon/")
import StepMiner as smn
import HegemonUtil as hu
acolor = ["#00CC00", "#D8A03D","#EC008C",
          'cyan', "#B741DC", "#808285",
          'blue', 'black', 'green', 'red',
          'orange', 'brown', 'pink', 'purple']

try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3     
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
import bone
reload(bone)
# Out:
# <module 'bone' from '/booleanfs2/sahoo/BoNE/bone.py'>

# %%
def ICAMomparison(ana, desc=''):
    def getL(l1):
        return '(' + ",".join([str(len(k)) for k in l1]) +')'
    res = []

    wt1, l1 = getAdultDegMac1()
    ann = [re.sub(" .*", "", ana.h.getSource()),'Hs','ICAM', getL(l1)]
    res += [ana.getStats(l1, wt1, ann)]
    
    wt1, l1 = getAdultDegMac2()
    ann = [re.sub(" .*", "", ana.h.getSource()),'Hs','ICBM', getL(l1)]
    res += [ana.getStats(l1, wt1, ann)]
    
    wt1, l1 = mut.getCls13a14a3()
    ann = [re.sub(" .*", "", ana.h.getSource()),'Hs','SMaRT', getL(l1)]
    res += [ana.getStats(l1, wt1, ann)]
    
    wt1, l1 = getCOATES()
    ann = [re.sub(" .*", "", ana.h.getSource()),'Hs','Coates', getL(l1)]
    res += [ana.getStats(l1, wt1, ann)]
    
    wt1, l1 = getYarilina()
    ann = [re.sub(" .*", "", ana.h.getSource()),'Hs','Yarilina', getL(l1)]
    res += [ana.getStats(l1, wt1, ann)]
    
    wt1, l1 = getRivollier()
    ann = [re.sub(" .*", "", ana.h.getSource()),'Hs','Rivollier', getL(l1)]
    res += [ana.getStats(l1, wt1, ann)]
    
    wt1, l1 = getFOSTER()
    ann = [re.sub(" .*", "", ana.h.getSource()),'Hs','Foster', getL(l1)]
    res += [ana.getStats(l1, wt1, ann)]
    
    wt1, l1 = getMartinez()
    ann = [re.sub(" .*", "", ana.h.getSource()),'Hs','Martinez', getL(l1)]
    res += [ana.getStats(l1, wt1, ann)]
    
    cols = ['GSEID', 'ROC-AUC', 'pvalue', '#Cont', '#Expt',
            'Series', 'Species', 'Signature', '#Genes']
    df = pd.DataFrame(res, columns=cols)
    df['Condition'] = desc
    return df
res = []
# Adult small intestine
ana.get_adult_Human_small_Intestinal()
desc = ana.atypes[0] + ' vs ' + ana.atypes[1]
res += [ICAMomparison(ana,desc=desc)]
# Adult large intestine
ana.get_adult_GSE158328_A_1_2_v1()
desc = ana.atypes[0] + ' vs ' + ana.atypes[1]
res += [ICAMomparison(ana,desc=desc)]
# Fetal intestine
ana.get_dev_fetal_v2() 
desc = ana.atypes[0] + ' vs ' + ana.atypes[1]
res += [ICAMomparison(ana,desc=desc)]
df = pd.concat(res)
df.to_csv("plots/ICAM-validation-results-2.txt", sep="\t")
# Out:
# SP Adult version_2 (n = 10)
# PMID: http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T9_1
# 10 [7, 3] PMID: http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T9_1 T9_1
# [7, 23, 29]
# [14, 62, 64]
# [47, 112, 120]
# [99, 55]
# [132, 123]
# [148, 134]
# [179, 582]
# [173, 154]
# ST ADULT s_a1_a2_v1 (n = 8)
# GSE158328 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T12_22
# 8 [4, 4] GSE158328 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T12_22 T12_22
# [7, 23, 26]
# [13, 62, 62]
# [45, 110, 115]
# [95, 53]
# [123, 115]
# [139, 129]
# [164, 567]
# [161, 141]
# ST Dev_Fetal_v2-precise-top_final (n = 11)
# GSE158328 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T12_6
# 11 [5, 6] GSE158328 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T12_6 T12_6
# [7, 23, 26]
# [13, 62, 63]
# [44, 110, 115]
# [95, 54]
# [128, 116]
# [137, 130]
# [157, 559]
# [163, 150]

# %%
def DP1(dfs): # VERTICAL

    if len(dfs) <= 0:
        return None
    df1 = dfs[0]
    df1['Name'] = list(df1['Signature'])
    df1['Xl'] = list(df1['#Genes'])
    labels = [k['GSEID'][0] + ' ' + k['Condition'][0] for k in dfs]
    n1 = df1.shape[0]
    rocauc = list(df1['ROC-AUC'])
    p = list(df1['pvalue'])
    y = [1] * n1
    for i in range(1, len(dfs)):
        rocauc += list(dfs[i]['ROC-AUC'])
        p += list(dfs[i]['pvalue'])
        y += [i+1] * n1
    df = pd.DataFrame()
    df['ROC-AUC'] = rocauc
    df['pvalue'] = p
    df['ROC-AUC'] = df['ROC-AUC'].apply(
               lambda x: max([float(k) for k in str(x).split(",")]))
    df['pvalue'] = df['pvalue'].apply(
               lambda x: min([float(k) for k in str(x).split(",")]))
    df['Y'] = y
    df['R'] = [(i - 0.5) if i !=200  else 200  for i in df['ROC-AUC']]      #df['ROC-AUC'] - 0.5
    df['Ra'] = [abs(i)+ 0.5  if i<1  else 0  for i in df['R'] ]     # abs(df['R']) + 0.5
    df['Ra1'] = [abs(i)+ 0.5  if i<1  else 0.51 if i==0 else 0.48  for i in df['R'] ]

    df['AUC'] = ['Up' if i > 0 else 'Down' for i in df['R']]
    #['Up' if i > 0 else 'Down' if i!=0 else 'NP' for i in df['R']]
    df['code'] = [bone.getCode(i) for i in df['pvalue']]
    df['ROC-AUC'] = df['Ra1']
    sns.set()
    sns.set_style("white")
    sns.set_style({'xtick.color':'.5', 'ytick.color':'.5', 'axes.labelcolor': '.5'})
    sns.set_context("notebook")
    sns.set_palette([bone.adj_light(c, 0.7, 1) for c in ['red', 'blue']])
    x = [i + 1 for i in range(n1)] * len(labels)
    y = df['Y']
    fig, ax = plt.subplots(figsize=(12, len(dfs)*0.7+1), dpi=100)
    ax = sns.scatterplot(x=x, y=y, size="ROC-AUC", hue='AUC',
                         sizes = (0, 100), size_norm = (0.49, 1),
                         hue_order = ['Up', 'Down'], ax=ax, data=df);
    roc = list(df['Ra'])
    code = list(df['code'])
    for line in range(n1):
        ax.text(line + 1, len(labels) + .5, df1['Xl'][line],
                horizontalalignment='center', size='small', color='0.8',
                verticalalignment='bottom', rotation=90)
        for i in range(len(labels)):
            ax.text(line + 1, i + 0.9, "%.2f" % roc[line + n1 * i],
                    horizontalalignment='right', size='small', color='0.8',
                    verticalalignment='top',  rotation=90)
            ax.text(line + 1.5, i + 0.9, code[line + n1 * i],
                     horizontalalignment='right', size='small', color='0.8',
                     verticalalignment='top',  rotation=90)

    x1 = [i + 1 for i in range(n1)]
    ax.set_yticks(range(1, len(labels) + 1))
    ax.set_yticklabels(labels)
    ax.set_xlim([0, len(x1)+1])
    ax.set_ylim([0, len(labels) + 2])
    ax.set_xticks(x1)
    ax.set_xticklabels(df1['Name'], rotation=90)
    ax.set_ylabel("")
    ax.grid(False)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels, bbox_to_anchor=(1.3, 1))
    return df,ax,fig

# %%
nsig = 8 # number of sigs 

df = pd.read_csv("plots/ICAM-validation-results-2.txt", sep="\t", index_col=0)
res = np.array_split(df, df.shape[0]/nsig, axis=0)
df1 = df.pivot_table(values='ROC-AUC', index=df.index, columns='Condition', aggfunc='last')
df1['Avg'] = df1.apply(pd.to_numeric).mean(axis=1)
df1['Name'] = [df.iloc[k, df.columns.get_loc("Signature")] for k in df1.index]
df1 = df1.sort_values('Avg', ascending=False)
ax = df1.plot.bar(x='Name', y='Avg', figsize=(2*24/9, 2))
ax.set_ylim([0.4, 0.9])
ax.set_ylabel("Avg ROC-AUC")
print(df1)
# pdf = getPDF("plots/validation-results.pdf")
# strname = "dot_plots_avg_roc-auc"
# plt.savefig(f'mac_{strname}.pdf', dpi=100, bbox_inches = 'tight')
df,ax,fig = DP1(res)
# pdf.savefig(transparent=True,bbox_inches = 'tight')
# strname = "dot_plots"
# fig.savefig(f'ICAM_{strname}.pdf', dpi=100, transparent=True,bbox_inches = 'tight')
# Out:
# Condition  Top vs Bottom   Avg       Name
# 2                   0.97  0.97      SMaRT
# 3                   0.97  0.97     Coates
# 1                   0.93  0.93       ICBM
# 5                   0.67  0.67  Rivollier
# 0                   0.63  0.63       ICAM
# 4                   0.53  0.53   Yarilina
# 7                   0.43  0.43   Martinez
# 6                   0.40  0.40     Foster
